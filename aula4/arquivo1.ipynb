# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
imagem = cv2.imread('ju.jpg')

# %%
type(imagem)
# Out:
# numpy.ndarray

# %%
 imagem.shape
# Out:
# (4160, 3120, 3)

# %%
plt.imshow(imagem)

# %%
#matplotlib trabalha com RGB
#open cv trabalha com BGR
corrige_imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(corrige_imagem)

# %%
imagem_escala_cinza = cv2.imread('ju.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagem_escala_cinza)
