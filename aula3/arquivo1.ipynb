# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
imagem = Image.open('rick.jpg')

# %%
type(imagem)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagem_vetor = np.asarray(imagem)

# %%
type(imagem_vetor)
# Out:
# numpy.ndarray

# %%
imagem_vetor.shape
# Out:
# (810, 540, 3)

# %%
plt.imshow(imagem_vetor)

# %%
copia_imagem = imagem_vetor.copy()

# %%
type(copia_imagem)
# Out:
# numpy.ndarray

# %%
plt.imshow(copia_imagem)

# %%
copia_imagem.shape
# Out:
# (810, 540, 3)

# %%
plt.imshow(copia_imagem[:,:,2], cmap ='gray')

# %%
copia_imagem
# Out:
# array([[[253, 254, 255],
#         [253, 254, 255],
#         [253, 254, 255],
#         ...,
#         [246, 255, 252],
#         [246, 255, 252],
#         [246, 255, 252]],
#
#        [[255, 254, 250],
#         [255, 254, 250],
#         [255, 254, 250],
#         ...,
#         [250, 255, 250],
#         [250, 255, 250],
#         [250, 255, 250]],
#
#        [[255, 253, 247],
#         [255, 253, 247],
#         [255, 253, 247],
#         ...,
#         [255, 254, 250],
#         [255, 254, 250],
#         [255, 254, 250]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
copia_imagem[:,:,1] = 0

# %%
copia_imagem
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 252],
#         [  0,   0, 252],
#         [  0,   0, 252]],
#
#        [[  0,   0, 250],
#         [  0,   0, 250],
#         [  0,   0, 250],
#         ...,
#         [  0,   0, 250],
#         [  0,   0, 250],
#         [  0,   0, 250]],
#
#        [[  0,   0, 247],
#         [  0,   0, 247],
#         [  0,   0, 247],
#         ...,
#         [  0,   0, 250],
#         [  0,   0, 250],
#         [  0,   0, 250]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]]], dtype=uint8)

# %%
plt.imshow(copia_imagem)
